# %% [markdown]
# ***DATA PREPROCESSING***
#
# Before loading the images and the labels (bounding boxes) into the model we need to ensure the data is in the right format. Also, we need to make sure we have enough images to train the model properly (data augmentation).

# %%
import numpy as np
import matplotlib.pyplot as plt
import os

#http://imageio.readthedocs.io/en/latest/userapi.html#module-imageio.core.functions

# %%
#the images are saved in two folders so we need to make sure we load all images. Let's start with the images and not the countour
path_name = ['C:\\Users\\martar\\OneDrive\\Documents\\Python course\\ADS\\Final Project\\melanoma','C:\\Users\\martar\\OneDrive\\Documents\\Python course\\ADS\\Final Project\\notmelanoma']

#We want to have two arrays melanoma and notmelanoma that inclure all images, so the shape of this array is going to be = number of images, image_dimension x, image_dimension y, number of channels

list_files = os.listdir(path_name[1])

melanoma_images_list = [name for name in os.listdir(path_name[0]) if name.endswith('orig.jpg')]
melanoma_contour_list = [name for name in os.listdir(path_name[0]) if name.endswith('contour.png')]

notmelanoma_images_list = [name for name in os.listdir(path_name[1]) if name.endswith('orig.jpg')]
notmelanoma_contour_list = [name for name in os.listdir(path_name[1]) if name.endswith('contour.png')]

# %% [markdown]
# ***STEP 0: SPLIT DATA INTO TRAIN AND TEST BEFORE WE DO ANYTHING ELSE TO AVOID LEAKAGE***

# %%
from sklearn.model_selection import train_test_split
melanoma_images_train, melanoma_images_test = train_test_split(melanoma_images_list,test_size=0.2, random_state=123)
notmelanoma_images_train, notmelanoma_images_test = train_test_split(notmelanoma_images_list,test_size=0.2, random_state=123)

# %% [markdown]
# ***STEP 1: DATA AUGMENTATION AND RESHAPE FUNCTION***
#
# Neural networks are normally trained with datasets of thousands of images. So...what we do to overcome that problem when we have limited number of images?? We can apply transformations to our images: rotation, flip, etc so we can generate more samples for the exiting one. There are many techniques to do this and keras has a module that already does this. However, because we need to apply the same transformation to the shape and the contour, we are going to implement our own pipeline
#
# https://medium.com/nanonets/how-to-use-deep-learning-when-you-have-limited-data-part-2-data-augmentation-c26971dc8ced
#
# https://www.researchgate.net/figure/Geometric-transformation-functions-for-image-registration-Note-that-affine_fig11_236125496
#
# Great tutorial on data augmentation
#
# https://github.com/aleju/imgaug

# %%
#Function to augment images

from skimage.transform import rotate, resize
from imgaug import augmenters as iaa
#This is a package built for image augmentation

def image_aug(input_image, image_size):
    
    origin_reshaped = resize(input_image,image_size)
    flip_image = np.fliplr(origin_reshaped)
    fliphor_image = np.flipud(origin_reshaped)
    rot45_image =  rotate(origin_reshaped, angle=45, mode='reflect')
    rot90_image =  rotate(origin_reshaped, angle=90, mode='reflect')
    crop = iaa.Crop(percent=(0, 0.3))
    crop_image = crop.augment_image(origin_reshaped)
    affine =  iaa.Affine(scale=1.5)
    affine_image = affine.augment_image(origin_reshaped)
    return origin_reshaped, flip_image, fliphor_image, rot45_image, rot90_image, crop_image, affine_image

# %%
#Testing random crop
from skimage.io import imread
seq = iaa.Affine(scale=1.5)
image_test = 'C:\\Users\\martar\\OneDrive\\Documents\\Python course\\ADS\\Final Project\\notmelanoma\\10_33_orig.jpg'

image = seq.augment_image(imread(image_test))

image_size_test = (192,192)
augmented_matrix = image_aug(imread(image_test), image_size_test)
augmented_matrix
# Out:
# C:\Users\martar\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\transform\_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# (array([[[0.77107928, 0.7373466 , 0.69892961],
#          [0.70521472, 0.65639936, 0.6080059 ],
#          [0.72773033, 0.66498523, 0.60616171],
#          ...,
#          [0.74302364, 0.68812168, 0.64498443],
#          [0.72143204, 0.65476537, 0.62004315],
#          [0.76185555, 0.69518889, 0.66046666]],
#
#         [[0.62476894, 0.58334738, 0.54192581],
#          [0.59113626, 0.53562155, 0.48231081],
#          [0.54899089, 0.48086512, 0.41739047],
#          ...,
#          [0.58021663, 0.51431143, 0.46729665],
#          [0.56282744, 0.49726371, 0.4547392 ],
#          [0.61593073, 0.55036701, 0.5078425 ]],
#
#         [[0.64089946, 0.58695172, 0.53471563],
#          [0.56116919, 0.49434487, 0.4318653 ],
#          [0.57683441, 0.5035052 , 0.42904837],
#          ...,
#          [0.61426462, 0.53975482, 0.48432181],
#          [0.5635506 , 0.5008055 , 0.44876302],
#          [0.57006293, 0.50731784, 0.45527535]],
#
#         ...,
#
#         [[0.62393216, 0.53373609, 0.47152203],
#          [0.52973856, 0.44738562, 0.36747217],
#          [0.52663803, 0.4612377 , 0.36718133],
#          ...,
#          [0.55696083, 0.48245102, 0.41578436],
#          [0.5754085 , 0.5126634 , 0.4499183 ],
#          [0.59922875, 0.53648365, 0.47373855]],
#
#         [[0.56456227, 0.52248711, 0.43515051],
#          [0.53367992, 0.46155982, 0.40506472],
#          [0.53286675, 0.44526463, 0.36954976],
#          ...,
#          [0.60522301, 0.55822546, 0.52293135],
#          [0.59877451, 0.53210784, 0.46936275],
#          [0.5475337 , 0.48086703, 0.41812194]],
#
#         [[0.56849788, 0.52642272, 0.43908612],
#          [0.60632468, 0.53420458, 0.47770948],
#          [0.54741583, 0.45981371, 0.38409884],
#          ...,
#          [0.65436602, 0.60736847, 0.57207435],
#          [0.55562449, 0.48895782, 0.42621272],
#          [0.59430785, 0.52764119, 0.46489609]]]),
#  array([[[0.76185555, 0.69518889, 0.66046666],
#          [0.72143204, 0.65476537, 0.62004315],
#          [0.74302364, 0.68812168, 0.64498443],
#          ...,
#          [0.72773033, 0.66498523, 0.60616171],
#          [0.70521472, 0.65639936, 0.6080059 ],
#          [0.77107928, 0.7373466 , 0.69892961]],
#
#         [[0.61593073, 0.55036701, 0.5078425 ],
#          [0.56282744, 0.49726371, 0.4547392 ],
#          [0.58021663, 0.51431143, 0.46729665],
#          ...,
#          [0.54899089, 0.48086512, 0.41739047],
#          [0.59113626, 0.53562155, 0.48231081],
#          [0.62476894, 0.58334738, 0.54192581]],
#
#         [[0.57006293, 0.50731784, 0.45527535],
#          [0.5635506 , 0.5008055 , 0.44876302],
#          [0.61426462, 0.53975482, 0.48432181],
#          ...,
#          [0.57683441, 0.5035052 , 0.42904837],
#          [0.56116919, 0.49434487, 0.4318653 ],
#          [0.64089946, 0.58695172, 0.53471563]],
#
#         ...,
#
#         [[0.59922875, 0.53648365, 0.47373855],
#          [0.5754085 , 0.5126634 , 0.4499183 ],
#          [0.55696083, 0.48245102, 0.41578436],
#          ...,
#          [0.52663803, 0.4612377 , 0.36718133],
#          [0.52973856, 0.44738562, 0.36747217],
#          [0.62393216, 0.53373609, 0.47152203]],
#
#         [[0.5475337 , 0.48086703, 0.41812194],
#          [0.59877451, 0.53210784, 0.46936275],
#          [0.60522301, 0.55822546, 0.52293135],
#          ...,
#          [0.53286675, 0.44526463, 0.36954976],
#          [0.53367992, 0.46155982, 0.40506472],
#          [0.56456227, 0.52248711, 0.43515051]],
#
#         [[0.59430785, 0.52764119, 0.46489609],
#          [0.55562449, 0.48895782, 0.42621272],
#          [0.65436602, 0.60736847, 0.57207435],
#          ...,
#          [0.54741583, 0.45981371, 0.38409884],
#          [0.60632468, 0.53420458, 0.47770948],
#          [0.56849788, 0.52642272, 0.43908612]]]),
#  array([[[0.56849788, 0.52642272, 0.43908612],
#          [0.60632468, 0.53420458, 0.47770948],
#          [0.54741583, 0.45981371, 0.38409884],
#          ...,
#          [0.65436602, 0.60736847, 0.57207435],
#          [0.55562449, 0.48895782, 0.42621272],
#          [0.59430785, 0.52764119, 0.46489609]],
#
#         [[0.56456227, 0.52248711, 0.43515051],
#          [0.53367992, 0.46155982, 0.40506472],
#          [0.53286675, 0.44526463, 0.36954976],
#          ...,
#          [0.60522301, 0.55822546, 0.52293135],
#          [0.59877451, 0.53210784, 0.46936275],
#          [0.5475337 , 0.48086703, 0.41812194]],
#
#         [[0.62393216, 0.53373609, 0.47152203],
#          [0.52973856, 0.44738562, 0.36747217],
#          [0.52663803, 0.4612377 , 0.36718133],
#          ...,
#          [0.55696083, 0.48245102, 0.41578436],
#          [0.5754085 , 0.5126634 , 0.4499183 ],
#          [0.59922875, 0.53648365, 0.47373855]],
#
#         ...,
#
#         [[0.64089946, 0.58695172, 0.53471563],
#          [0.56116919, 0.49434487, 0.4318653 ],
#          [0.57683441, 0.5035052 , 0.42904837],
#          ...,
#          [0.61426462, 0.53975482, 0.48432181],
#          [0.5635506 , 0.5008055 , 0.44876302],
#          [0.57006293, 0.50731784, 0.45527535]],
#
#         [[0.62476894, 0.58334738, 0.54192581],
#          [0.59113626, 0.53562155, 0.48231081],
#          [0.54899089, 0.48086512, 0.41739047],
#          ...,
#          [0.58021663, 0.51431143, 0.46729665],
#          [0.56282744, 0.49726371, 0.4547392 ],
#          [0.61593073, 0.55036701, 0.5078425 ]],
#
#         [[0.77107928, 0.7373466 , 0.69892961],
#          [0.70521472, 0.65639936, 0.6080059 ],
#          [0.72773033, 0.66498523, 0.60616171],
#          ...,
#          [0.74302364, 0.68812168, 0.64498443],
#          [0.72143204, 0.65476537, 0.62004315],
#          [0.76185555, 0.69518889, 0.66046666]]]),
#  array([[[0.68752744, 0.63720729, 0.60614392],
#          [0.67507477, 0.63848774, 0.60161299],
#          [0.68333601, 0.65098779, 0.60962831],
#          ...,
#          [0.74463579, 0.67248091, 0.6139938 ],
#          [0.68499205, 0.63224795, 0.5765338 ],
#          [0.68775835, 0.64209985, 0.58673111]],
#
#         [[0.69428079, 0.64248822, 0.6144706 ],
#          [0.6688027 , 0.62515964, 0.59513331],
#          [0.71574039, 0.6779722 , 0.64004116],
#          ...,
#          [0.73940039, 0.68665628, 0.63094213],
#          [0.70205727, 0.65356342, 0.59937898],
#          [0.69392329, 0.64620905, 0.59162749]],
#
#         [[0.70541419, 0.65084865, 0.60928804],
#          [0.65290524, 0.5985266 , 0.56436998],
#          [0.68857009, 0.63731188, 0.59730417],
#          ...,
#          [0.720889  , 0.66935929, 0.61641812],
#          [0.70697405, 0.65222098, 0.60062836],
#          [0.7517578 , 0.69794014, 0.64623311]],
#
#         ...,
#
#         [[0.61093756, 0.48659778, 0.38398108],
#          [0.60810413, 0.50191775, 0.39581704],
#          [0.60689773, 0.50573625, 0.40360776],
#          ...,
#          [0.68184669, 0.61334188, 0.543103  ],
#          [0.67615004, 0.60948337, 0.54673827],
#          [0.67903642, 0.61236975, 0.54962466]],
#
#         [[0.60034761, 0.46482638, 0.35405856],
#          [0.61352401, 0.50187844, 0.38916182],
#          [0.61133672, 0.50630816, 0.39819659],
#          ...,
#          [0.68887778, 0.61922259, 0.55623912],
#          [0.68206912, 0.61540245, 0.55265735],
#          [0.66409478, 0.59742812, 0.53468302]],
#
#         [[0.57005222, 0.43985228, 0.3454012 ],
#          [0.59059388, 0.4435499 , 0.33026442],
#          [0.59862926, 0.48231848, 0.37438747],
#          ...,
#          [0.71377255, 0.62527228, 0.55468221],
#          [0.66478695, 0.59189387, 0.52615716],
#          [0.68689632, 0.62022966, 0.55748456]]]),
#  array([[[0.76185555, 0.69518889, 0.66046666],
#          [0.61593073, 0.55036701, 0.5078425 ],
#          [0.57006293, 0.50731784, 0.45527535],
#          ...,
#          [0.59922875, 0.53648365, 0.47373855],
#          [0.5475337 , 0.48086703, 0.41812194],
#          [0.59430785, 0.52764119, 0.46489609]],
#
#         [[0.72143204, 0.65476537, 0.62004315],
#          [0.56282744, 0.49726371, 0.4547392 ],
#          [0.5635506 , 0.5008055 , 0.44876302],
#          ...,
#          [0.5754085 , 0.5126634 , 0.4499183 ],
#          [0.59877451, 0.53210784, 0.46936275],
#          [0.55562449, 0.48895782, 0.42621272]],
#
#         [[0.74302364, 0.68812168, 0.64498443],
#          [0.58021663, 0.51431143, 0.46729665],
#          [0.61426462, 0.53975482, 0.48432181],
#          ...,
#          [0.55696083, 0.48245102, 0.41578436],
#          [0.60522301, 0.55822546, 0.52293135],
#          [0.65436602, 0.60736847, 0.57207435]],
#
#         ...,
#
#         [[0.72773033, 0.66498523, 0.60616171],
#          [0.54899089, 0.48086512, 0.41739047],
#          [0.57683441, 0.5035052 , 0.42904837],
#          ...,
#          [0.52663803, 0.4612377 , 0.36718133],
#          [0.53286675, 0.44526463, 0.36954976],
#          [0.54741583, 0.45981371, 0.38409884]],
#
#         [[0.70521472, 0.65639936, 0.6080059 ],
#          [0.59113626, 0.53562155, 0.48231081],
#          [0.56116919, 0.49434487, 0.4318653 ],
#          ...,
#          [0.52973856, 0.44738562, 0.36747217],
#          [0.53367992, 0.46155982, 0.40506472],
#          [0.60632468, 0.53420458, 0.47770948]],
#
#         [[0.77107928, 0.7373466 , 0.69892961],
#          [0.62476894, 0.58334738, 0.54192581],
#          [0.64089946, 0.58695172, 0.53471563],
#          ...,
#          [0.62393216, 0.53373609, 0.47152203],
#          [0.56456227, 0.52248711, 0.43515051],
#          [0.56849788, 0.52642272, 0.43908612]]]),
#  array([[[0.59714265, 0.53047598, 0.45988775],
#          [0.58150759, 0.51798273, 0.45669168],
#          [0.57907358, 0.51641018, 0.45766835],
#          ...,
#          [0.58587424, 0.53881542, 0.47615202],
#          [0.59312696, 0.53933467, 0.46992021],
#          [0.61176407, 0.53341439, 0.43937845]],
#
#         [[0.59343989, 0.52358959, 0.44545499],
#          [0.594313  , 0.53004136, 0.46706471],
#          [0.61030241, 0.54756041, 0.48873997],
#          ...,
#          [0.59206581, 0.5412338 , 0.47849179],
#          [0.58110305, 0.52433261, 0.45483954],
#          [0.58711186, 0.50868358, 0.41456902]],
#
#         [[0.61174434, 0.54120247, 0.45771148],
#          [0.59667549, 0.53026719, 0.46329069],
#          [0.59556794, 0.53029304, 0.4678447 ],
#          ...,
#          [0.62723241, 0.56866259, 0.5048225 ],
#          [0.64186661, 0.58011156, 0.51084483],
#          [0.59421618, 0.52084443, 0.4317864 ]],
#
#         ...,
#
#         [[0.59057883, 0.54352   , 0.48466515],
#          [0.61449939, 0.55647952, 0.49073252],
#          [0.60703684, 0.5450319 , 0.48023232],
#          ...,
#          [0.62633485, 0.54947544, 0.49713207],
#          [0.64625233, 0.56347519, 0.50675703],
#          [0.63964041, 0.57680567, 0.51768537]],
#
#         [[0.57032434, 0.52326552, 0.4692896 ],
#          [0.58337089, 0.52400132, 0.46596671],
#          [0.59200187, 0.52925678, 0.46879043],
#          ...,
#          [0.60824058, 0.53047738, 0.47899359],
#          [0.62384992, 0.54220361, 0.48505076],
#          [0.63002773, 0.56599443, 0.50324934]],
#
#         [[0.59477124, 0.54771242, 0.50065359],
#          [0.58821713, 0.52884756, 0.47351745],
#          [0.58930755, 0.52656245, 0.46826635],
#          ...,
#          [0.62545998, 0.55475587, 0.508347  ],
#          [0.61733973, 0.54293276, 0.48796003],
#          [0.60159314, 0.53492647, 0.47218137]]]),
#  array([[[0.65185706, 0.56893699, 0.49034164],
#          [0.65525486, 0.57447963, 0.49892262],
#          [0.66127273, 0.58320937, 0.51157292],
#          ...,
#          [0.71094502, 0.63643521, 0.57294423],
#          [0.68727671, 0.61471049, 0.54337939],
#          [0.65259542, 0.58197815, 0.50278179]],
#
#         [[0.65826254, 0.56565277, 0.48129318],
#          [0.65548375, 0.56614589, 0.48375747],
#          [0.655149  , 0.57051422, 0.49181809],
#          ...,
#          [0.68717315, 0.61266335, 0.55022863],
#          [0.6721785 , 0.59962948, 0.52868051],
#          [0.64611454, 0.57552631, 0.49597725]],
#
#         [[0.65484327, 0.55837728, 0.47229852],
#          [0.65375333, 0.56064468, 0.4756891 ],
#          [0.65394573, 0.56602632, 0.48443586],
#          ...,
#          [0.65247755, 0.57723776, 0.51509205],
#          [0.64904479, 0.57470436, 0.50356176],
#          [0.63935915, 0.56593022, 0.48583215]],
#
#         ...,
#
#         [[0.62866332, 0.54234668, 0.46981873],
#          [0.64854403, 0.55901176, 0.48036593],
#          [0.65563308, 0.56329048, 0.47675555],
#          ...,
#          [0.64764907, 0.60722532, 0.57359368],
#          [0.71830379, 0.68565806, 0.65805236],
#          [0.78055375, 0.75128276, 0.72667859]],
#
#         [[0.64101258, 0.55469595, 0.48216799],
#          [0.6418107 , 0.55227843, 0.4736326 ],
#          [0.64213472, 0.54979212, 0.46325719],
#          ...,
#          [0.69474489, 0.65739999, 0.62706241],
#          [0.75135144, 0.72104609, 0.6956427 ],
#          [0.78853095, 0.76104718, 0.73782273]],
#
#         [[0.64831449, 0.56199785, 0.48946989],
#          [0.63367937, 0.5441471 , 0.46550126],
#          [0.63085731, 0.53851471, 0.45197978],
#          ...,
#          [0.74467022, 0.71032203, 0.68304685],
#          [0.78826026, 0.76042358, 0.73740406],
#          [0.80444896, 0.77910826, 0.75782645]]]))

# %% [markdown]
# ***STEP 2: AUGMENT AND SAVE IMAGES AND COUNTOURS IN THE FOLDER***

# %%
import imageio as io
from skimage.io import imread

def aug_and_save_image(input_image, path_name, image_size):
    input_image_name = input_image
    new_image_path = path_name+'\\preprocessed_data'+'\\'+input_image
    input_image = imread(path_name+'\\'+input_image)
    input_image_array = np.asarray(input_image)
    augmented_array = image_aug(input_image_array, image_size)
    file_name = new_image_path[:-4]
    file_format = input_image_name[-4:]
    augmentation_list = ['origin_reshaped', 'flip_image', 'fliphor_image', 'rot45_image', 'rot90_image', 'crop_image', 'affine_image']
    for index, augmentation in enumerate(augmentation_list):
        #save image
        if augmentation == 'origin_reshaped':
            io.imsave(file_name + file_format,augmented_array[index])
        else:
            io.imsave(file_name + augmentation+ file_format,augmented_array[index])

# %%
def get_bounding_box(input_image,path_name):
    input_image_name = input_image
    input_image = imread(path_name+'\\'+input_image)
    tmp = np.argwhere(input_image)
    top_left = np.amin(tmp, axis=0)
    bottom_right = np.amax(tmp, axis=0)
    output_matrix  = [top_left,bottom_right]
    file_name = path_name+'\\'+input_image_name[:-4]+'_bounding_box.txt'
    np.savetxt(file_name, output_matrix)

# %%
#Create a new folder for the augmented and reshaped images
os.makedirs(path_name[0]+'\\preprocessed_data')
os.makedirs(path_name[1]+'\\preprocessed_data')

# %%
#Saving melanoma test images 
image_size = (192,192)
for name in melanoma_images_test:
    io.imsave(path_name[0]+'\\preprocessed_data\\'+'test'+name,resize(imread(path_name[0]+'\\'+name),image_size))
    contour = name.replace("orig.jpg","contour.png")
    io.imsave(path_name[0]+'\\preprocessed_data\\'+'test'+contour,resize(imread(path_name[0]+'\\'+contour),image_size))
    
#Saving notmelanoma test images
for name in notmelanoma_images_test:
    io.imsave(path_name[1]+'\\preprocessed_data\\'+'test'+name,resize(imread(path_name[1]+'\\'+name),image_size))
    contour = name.replace("orig.jpg","contour.png")
    io.imsave(path_name[1]+'\\preprocessed_data\\'+'test'+contour,resize(imread(path_name[1]+'\\'+contour),image_size))
# Out:
# C:\Users\martar\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\transform\_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# C:\Users\martar\AppData\Local\Continuum\anaconda3\lib\site-packages\imageio\core\util.py:78: UserWarning: Lossy conversion from float64 to uint8, range [0, 1]
#   dtype_str, out_type.__name__))

# %%
melanoma_images_test[1]
# Out:
# '75_SSM30_2_orig.jpg'

# %%
image_size = (192,192)
#augmenting and saving traininig melanoma images
for name in melanoma_images_train:
    aug_and_save_image(name, path_name[0], image_size)
    contour = name.replace("orig.jpg","contour.png")
    aug_and_save_image(contour, path_name[0], image_size)
#augmenting and saving traininig notmelanoma images
for name in notmelanoma_images_train:
    aug_and_save_image(name, path_name[1], image_size)
    contour = name.replace("orig.jpg","contour.png")
    aug_and_save_image(contour, path_name[1], image_size)
# Out:
# C:\Users\martar\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\transform\_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# C:\Users\martar\AppData\Local\Continuum\anaconda3\lib\site-packages\imageio\core\util.py:78: UserWarning: Lossy conversion from float64 to uint8, range [0, 1]
#   dtype_str, out_type.__name__))
# C:\Users\martar\AppData\Local\Continuum\anaconda3\lib\site-packages\imageio\core\util.py:104: UserWarning: Conversion from float64 to uint8, range [0.0, 1.0000000596046457]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# C:\Users\martar\AppData\Local\Continuum\anaconda3\lib\site-packages\imageio\core\util.py:104: UserWarning: Conversion from float64 to uint8, range [0.0, 1.0000000298023224]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# C:\Users\martar\AppData\Local\Continuum\anaconda3\lib\site-packages\imageio\core\util.py:104: UserWarning: Conversion from float64 to uint8, range [0.1377981472291791, 1.0000000298023224]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# C:\Users\martar\AppData\Local\Continuum\anaconda3\lib\site-packages\imageio\core\util.py:104: UserWarning: Conversion from float64 to uint8, range [0.0, 1.0000000149011612]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# C:\Users\martar\AppData\Local\Continuum\anaconda3\lib\site-packages\imageio\core\util.py:104: UserWarning: Conversion from float64 to uint8, range [0.0, 1.0000000298023357]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# C:\Users\martar\AppData\Local\Continuum\anaconda3\lib\site-packages\imageio\core\util.py:104: UserWarning: Conversion from float64 to uint8, range [0.02081189537548579, 1.0000000298023224]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# C:\Users\martar\AppData\Local\Continuum\anaconda3\lib\site-packages\imageio\core\util.py:104: UserWarning: Conversion from float64 to uint8, range [0.0, 1.0000000037252903]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# C:\Users\martar\AppData\Local\Continuum\anaconda3\lib\site-packages\imageio\core\util.py:104: UserWarning: Conversion from float64 to uint8, range [0.014960524718756866, 1.0000000298023224]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# C:\Users\martar\AppData\Local\Continuum\anaconda3\lib\site-packages\imageio\core\util.py:104: UserWarning: Conversion from float64 to uint8, range [0.0, 1.0000000372529032]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# C:\Users\martar\AppData\Local\Continuum\anaconda3\lib\site-packages\imageio\core\util.py:104: UserWarning: Conversion from float64 to uint8, range [0.0, 1.0000000223517418]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# C:\Users\martar\AppData\Local\Continuum\anaconda3\lib\site-packages\imageio\core\util.py:104: UserWarning: Conversion from float64 to uint8, range [0.029487830200355156, 1.0000000298023224]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# C:\Users\martar\AppData\Local\Continuum\anaconda3\lib\site-packages\imageio\core\util.py:104: UserWarning: Conversion from float64 to uint8, range [0.0006410420070804784, 1.0000000298023224]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# C:\Users\martar\AppData\Local\Continuum\anaconda3\lib\site-packages\imageio\core\util.py:104: UserWarning: Conversion from float64 to uint8, range [0.0, 1.000000044703484]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# C:\Users\martar\AppData\Local\Continuum\anaconda3\lib\site-packages\imageio\core\util.py:104: UserWarning: Conversion from float64 to uint8, range [0.001459099264707502, 1.0000000149011612]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# C:\Users\martar\AppData\Local\Continuum\anaconda3\lib\site-packages\imageio\core\util.py:104: UserWarning: Conversion from float64 to uint8, range [0.0, 1.000000033527613]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# C:\Users\martar\AppData\Local\Continuum\anaconda3\lib\site-packages\imageio\core\util.py:104: UserWarning: Conversion from float64 to uint8, range [0.0006635550863424607, 1.0000000298023224]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# C:\Users\martar\AppData\Local\Continuum\anaconda3\lib\site-packages\imageio\core\util.py:104: UserWarning: Conversion from float64 to uint8, range [0.06992500772251393, 1.0000000149011612]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# C:\Users\martar\AppData\Local\Continuum\anaconda3\lib\site-packages\imageio\core\util.py:104: UserWarning: Conversion from float64 to uint8, range [0.1750784242551682, 1.0000000149011612]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# C:\Users\martar\AppData\Local\Continuum\anaconda3\lib\site-packages\imageio\core\util.py:104: UserWarning: Conversion from float64 to uint8, range [0.0060070646190612705, 1.0000000149011612]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# C:\Users\martar\AppData\Local\Continuum\anaconda3\lib\site-packages\imageio\core\util.py:104: UserWarning: Conversion from float64 to uint8, range [0.00202482468681877, 1.0000000298023224]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))

# %%
#Get the bounding boxes for all images:
new_path_name = [path +'\\preprocessed_data' for path in path_name]

for path in new_path_name:
    new_list_files = os.listdir(path)
    list_augmented = [name for name in new_list_files if 'contour' in name]
    for name2 in list_augmented:
        get_bounding_box(name2,path)

# %% [markdown]
# ***STEP 3: GET THE DATA IN THE RIGHT FORMAT ***
#
# [filename,width,height, class, xmin, ymin, xmax,ymax]
#
# raccoon-17.jpg	259	194	raccoon	95	60	167	118

# %%
entry_df = pd.DataFrame()

for index_path, path in enumerate(new_path_name):
   
    
    #filename = name of the original image
    file_name_list = [name for name in os.listdir(path) if 'orig' in name]
    
    #As we reshaped all the images to be 200*200
    image_width = np.zeros(shape = len(file_name_list))
    image_width.fill(192)
    image_height = np.zeros(shape = len(file_name_list))
    image_height.fill(192)

    #for now, we are only looking at melanoma 
    image_class = [np.empty(shape = len(file_name_list))]
    
    if index_path == 0:
        image_class = "melanoma"
    else:
        image_class = "notmelanoma"


    #xmin, ymin = top_left from the bounding box function
    #xmax, ymax = bottom_right from the bounding box funtion

    x_min_list = np.zeros(shape = len(file_name_list))
    y_min_list = np.zeros(shape = len(file_name_list))
    x_max_list = np.zeros(shape = len(file_name_list))
    y_max_list = np.zeros(shape = len(file_name_list))

    for index,file_name in enumerate(file_name_list):
        file_name_search = file_name.replace('orig','contour')[:-4]+'_bounding_box.txt'
        found_file_name = [name for name in os.listdir(path) if file_name_search in name]
        box_array = np.loadtxt(path+"\\"+ found_file_name[0])
    
        x_min_list[index] = box_array[0][0]
        y_min_list[index] = box_array[0][1]
        x_max_list[index] = box_array[1][0]
        y_max_list[index] = box_array[1][1]
        
    entry = {"filename":file_name_list, 
             "width": image_width, 
             "height": image_height, 
             "class": image_class, 
             "xmin": x_min_list, 
             "ymin": y_min_list, 
             "xmax": x_max_list, 
             "ymax": y_max_list}
    
    entry_aux_df= pd.DataFrame.from_dict(entry)
    entry_aux_df["path_name"] = path
    entry_aux_df.set_index("filename",inplace=True)
    
    entry_df = pd.concat([entry_df, entry_aux_df])

# %%
entry_df["xmin_norm"] = entry_df["xmin"]/entry_df["width"]
entry_df["ymin_norm"] = entry_df["ymin"]/entry_df["height"]
entry_df["box_width"] = (entry_df["xmax"] - entry_df["xmin"])/entry_df["width"]
entry_df["box_height"] = (entry_df["ymax"] - entry_df["ymin"])/entry_df["height"]

# %%
entry_df.head()
# Out:
#                                     class  height  width   xmax  xmin   ymax  \
# filename
# 100_SSM65_orig.jpg               melanoma   192.0  192.0  132.0  66.0  108.0
# 100_SSM65_origaffine_image.jpg   melanoma   192.0  192.0  151.0  50.0  115.0
# 100_SSM65_origcrop_image.jpg     melanoma   192.0  192.0  133.0  42.0  142.0
# 100_SSM65_origfliphor_image.jpg  melanoma   192.0  192.0  125.0  59.0  108.0
# 100_SSM65_origflip_image.jpg     melanoma   192.0  192.0  132.0  66.0  122.0
#
#                                  ymin  \
# filename
# 100_SSM65_orig.jpg               69.0
# 100_SSM65_origaffine_image.jpg   55.0
# 100_SSM65_origcrop_image.jpg     79.0
# 100_SSM65_origfliphor_image.jpg  69.0
# 100_SSM65_origflip_image.jpg     83.0
#
#                                                                          path_name  \
# filename
# 100_SSM65_orig.jpg               C:\Users\martar\OneDrive\Documents\Python cour...
# 100_SSM65_origaffine_image.jpg   C:\Users\martar\OneDrive\Documents\Python cour...
# 100_SSM65_origcrop_image.jpg     C:\Users\martar\OneDrive\Documents\Python cour...
# 100_SSM65_origfliphor_image.jpg  C:\Users\martar\OneDrive\Documents\Python cour...
# 100_SSM65_origflip_image.jpg     C:\Users\martar\OneDrive\Documents\Python cour...
#
#                                  xmin_norm  ymin_norm  box_width  box_height
# filename
# 100_SSM65_orig.jpg                0.343750   0.359375   0.343750    0.203125
# 100_SSM65_origaffine_image.jpg    0.260417   0.286458   0.526042    0.312500
# 100_SSM65_origcrop_image.jpg      0.218750   0.411458   0.473958    0.328125
# 100_SSM65_origfliphor_image.jpg   0.307292   0.359375   0.343750    0.203125
# 100_SSM65_origflip_image.jpg      0.343750   0.432292   0.343750    0.203125

# %% [markdown]
# ***STEP 4: Shuffle and then save the train and test files***
# We need to shuffle to prevent the network from learning

# %%
entry_df.reindex(np.random.permutation(entry_df.index))
# Out:
#                                        class  height  width   xmax  xmin  \
# filename
# 44_D24_origrot90_image.jpg       notmelanoma   192.0  192.0  111.0  90.0
# 19_48_origcrop_image.jpg         notmelanoma   192.0  192.0  191.0   0.0
# 11_SSM10_origflip_image.jpg         melanoma   192.0  192.0  149.0  27.0
# 5_25_orig.jpg                    notmelanoma   192.0  192.0  152.0  39.0
# 18_46_origaffine_image.jpg       notmelanoma   192.0  192.0  162.0  61.0
# 80_D57_2_orig.jpg                notmelanoma   192.0  192.0  140.0  56.0
# 85_SSM40_origflip_image.jpg         melanoma   192.0  192.0  137.0  77.0
# 118_SSM9_origrot90_image.jpg        melanoma   192.0  192.0  111.0  83.0
# 40_SSM5_origrot45_image.jpg         melanoma   192.0  192.0  137.0   0.0
# 52_NM61_origflip_image.jpg          melanoma   192.0  192.0  160.0  59.0
# 81_D57_origrot45_image.jpg       notmelanoma   192.0  192.0  128.0  76.0
# 7_NM3_origrot90_image.jpg           melanoma   192.0  192.0  147.0  54.0
# 29_D11_origcrop_image.jpg        notmelanoma   192.0  192.0  118.0  76.0
# test0_AMM1_orig.jpg                 melanoma   192.0  192.0  162.0  73.0
# test75_SSM30_2_orig.jpg             melanoma   192.0  192.0  144.0  86.0
# 77_D54_orig.jpg                  notmelanoma   192.0  192.0  145.0  77.0
# 45_LMM2_origaffine_image.jpg        melanoma   192.0  192.0  136.0  79.0
# 7_NM3_orig.jpg                      melanoma   192.0  192.0  160.0  21.0
# 10_33_origrot90_image.jpg        notmelanoma   192.0  192.0  158.0  80.0
# 52_D33_origrot90_image.jpg       notmelanoma   192.0  192.0  106.0  86.0
# 113_SSM85_2_origcrop_image.jpg      melanoma   192.0  192.0  191.0  42.0
# 65_D45_2_origfliphor_image.jpg   notmelanoma   192.0  192.0  145.0  51.0
# 93_SSM55_2_origaffine_image.jpg     melanoma   192.0  192.0  178.0  34.0
# 23_7_origrot90_image.jpg         notmelanoma   192.0  192.0  139.0  53.0
# test22_SSM20_orig.jpg               melanoma   192.0  192.0  155.0  55.0
# 69_SSM26_origaffine_image.jpg       melanoma   192.0  192.0  169.0  16.0
# 27_D10_origfliphor_image.jpg     notmelanoma   192.0  192.0  116.0  68.0
# 38_SSM3_origaffine_image.jpg        melanoma   192.0  192.0  191.0   0.0
# 61_SSM19_origfliphor_image.jpg      melanoma   192.0  192.0  147.0  96.0
# 52_D33_origaffine_image.jpg      notmelanoma   192.0  192.0  150.0  76.0
# ...                                      ...     ...    ...    ...   ...
# 9_32_origrot45_image.jpg         notmelanoma   192.0  192.0  122.0  74.0
# 80_D57_2_origaffine_image.jpg    notmelanoma   192.0  192.0  163.0  35.0
# 85_SSM40_origfliphor_image.jpg      melanoma   192.0  192.0  114.0  54.0
# 3_LMM4_origrot90_image.jpg          melanoma   192.0  192.0  102.0  34.0
# 53_NM83_orig.jpg                    melanoma   192.0  192.0  125.0  36.0
# 48_D28_2_origrot45_image.jpg     notmelanoma   192.0  192.0  134.0  60.0
# 11_34_origaffine_image.jpg       notmelanoma   192.0  192.0  191.0  29.0
# 37_D19_2_origaffine_image.jpg    notmelanoma   192.0  192.0  160.0  43.0
# 31_SSM29_origrot45_image.jpg        melanoma   192.0  192.0  135.0  53.0
# 8_29_origrot45_image.jpg         notmelanoma   192.0  192.0  136.0  59.0
# 52_NM61_origrot90_image.jpg         melanoma   192.0  192.0  109.0  79.0
# 23_SSM21_origrot45_image.jpg        melanoma   192.0  192.0  112.0   0.0
# 100_SSM65_origaffine_image.jpg      melanoma   192.0  192.0  151.0  50.0
# 32_SSM2_origcrop_image.jpg          melanoma   192.0  192.0  191.0   0.0
# 61_D40_origrot90_image.jpg       notmelanoma   192.0  192.0  105.0  79.0
# 33_SSM30_orig.jpg                   melanoma   192.0  192.0  129.0  42.0
# 70_D51_1_origcrop_image.jpg      notmelanoma   192.0  192.0  171.0  72.0
# 66_SSM23_origflip_image.jpg         melanoma   192.0  192.0  113.0  67.0
# 37_SSM34_origaffine_image.jpg       melanoma   192.0  192.0  132.0  31.0
# 18_SSM17_origcrop_image.jpg         melanoma   192.0  192.0  164.0  53.0
# 57_D38_2_origflip_image.jpg      notmelanoma   192.0  192.0  113.0  73.0
# 101_SSM68_origfliphor_image.jpg     melanoma   192.0  192.0  132.0  68.0
# 21_4_origrot45_image.jpg         notmelanoma   192.0  192.0  122.0  91.0
# 33_SSM30_origaffine_image.jpg       melanoma   192.0  192.0  147.0  14.0
# 15_SSM14_origaffine_image.jpg       melanoma   192.0  192.0  184.0  31.0
# test114_SSM85_orig.jpg              melanoma   192.0  192.0  133.0  76.0
# 35_SSM32_origrot90_image.jpg        melanoma   192.0  192.0  123.0  60.0
# 15_41_orig.jpg                   notmelanoma   192.0  192.0  138.0  71.0
# 110_SSM7_origaffine_image.jpg       melanoma   192.0  192.0  117.0  77.0
# 10_33_origrot45_image.jpg        notmelanoma   192.0  192.0  191.0  62.0
#
#                                   ymax   ymin  \
# filename
# 44_D24_origrot90_image.jpg       120.0   73.0
# 19_48_origcrop_image.jpg         191.0   40.0
# 11_SSM10_origflip_image.jpg      149.0   32.0
# 5_25_orig.jpg                    111.0   58.0
# 18_46_origaffine_image.jpg       136.0   55.0
# 80_D57_2_orig.jpg                115.0   88.0
# 85_SSM40_origflip_image.jpg      115.0   71.0
# 118_SSM9_origrot90_image.jpg     122.0   74.0
# 40_SSM5_origrot45_image.jpg      191.0    0.0
# 52_NM61_origflip_image.jpg       109.0   79.0
# 81_D57_origrot45_image.jpg       126.0   74.0
# 7_NM3_origrot90_image.jpg        160.0   21.0
# 29_D11_origcrop_image.jpg        101.0   69.0
# test0_AMM1_orig.jpg              130.0   92.0
# test75_SSM30_2_orig.jpg          149.0   70.0
# 77_D54_orig.jpg                  103.0   72.0
# 45_LMM2_origaffine_image.jpg     126.0   13.0
# 7_NM3_orig.jpg                   137.0   44.0
# 10_33_origrot90_image.jpg        150.0   46.0
# 52_D33_origrot90_image.jpg       131.0   83.0
# 113_SSM85_2_origcrop_image.jpg   114.0   57.0
# 65_D45_2_origfliphor_image.jpg   124.0   79.0
# 93_SSM55_2_origaffine_image.jpg  141.0   40.0
# 23_7_origrot90_image.jpg         181.0   16.0
# test22_SSM20_orig.jpg            164.0   69.0
# 69_SSM26_origaffine_image.jpg    126.0   28.0
# 27_D10_origfliphor_image.jpg      91.0   61.0
# 38_SSM3_origaffine_image.jpg     191.0    0.0
# 61_SSM19_origfliphor_image.jpg   124.0   60.0
# 52_D33_origaffine_image.jpg      111.0   79.0
# ...                                ...    ...
# 9_32_origrot45_image.jpg         139.0  105.0
# 80_D57_2_origaffine_image.jpg    126.0   83.0
# 85_SSM40_origfliphor_image.jpg   120.0   76.0
# 3_LMM4_origrot90_image.jpg       146.0   68.0
# 53_NM83_orig.jpg                 118.0   74.0
# 48_D28_2_origrot45_image.jpg     159.0   46.0
# 11_34_origaffine_image.jpg       147.0   41.0
# 37_D19_2_origaffine_image.jpg    124.0   55.0
# 31_SSM29_origrot45_image.jpg     129.0   65.0
# 8_29_origrot45_image.jpg         141.0   77.0
# 52_NM61_origrot90_image.jpg      160.0   59.0
# 23_SSM21_origrot45_image.jpg     117.0    0.0
# 100_SSM65_origaffine_image.jpg   115.0   55.0
# 32_SSM2_origcrop_image.jpg       191.0   22.0
# 61_D40_origrot90_image.jpg       111.0   78.0
# 33_SSM30_orig.jpg                114.0   70.0
# 70_D51_1_origcrop_image.jpg      123.0   81.0
# 66_SSM23_origflip_image.jpg      103.0   80.0
# 37_SSM34_origaffine_image.jpg    191.0   11.0
# 18_SSM17_origcrop_image.jpg      107.0   48.0
# 57_D38_2_origflip_image.jpg      115.0   79.0
# 101_SSM68_origfliphor_image.jpg  105.0   75.0
# 21_4_origrot45_image.jpg         119.0   86.0
# 33_SSM30_origaffine_image.jpg    124.0   56.0
# 15_SSM14_origaffine_image.jpg    169.0   94.0
# test114_SSM85_orig.jpg            99.0   76.0
# 35_SSM32_origrot90_image.jpg     149.0   65.0
# 15_41_orig.jpg                   133.0   67.0
# 110_SSM7_origaffine_image.jpg    115.0   79.0
# 10_33_origrot45_image.jpg        127.0    0.0
#
#                                                                          path_name  \
# filename
# 44_D24_origrot90_image.jpg       C:\Users\martar\OneDrive\Documents\Python cour...
# 19_48_origcrop_image.jpg         C:\Users\martar\OneDrive\Documents\Python cour...
# 11_SSM10_origflip_image.jpg      C:\Users\martar\OneDrive\Documents\Python cour...
# 5_25_orig.jpg                    C:\Users\martar\OneDrive\Documents\Python cour...
# 18_46_origaffine_image.jpg       C:\Users\martar\OneDrive\Documents\Python cour...
# 80_D57_2_orig.jpg                C:\Users\martar\OneDrive\Documents\Python cour...
# 85_SSM40_origflip_image.jpg      C:\Users\martar\OneDrive\Documents\Python cour...
# 118_SSM9_origrot90_image.jpg     C:\Users\martar\OneDrive\Documents\Python cour...
# 40_SSM5_origrot45_image.jpg      C:\Users\martar\OneDrive\Documents\Python cour...
# 52_NM61_origflip_image.jpg       C:\Users\martar\OneDrive\Documents\Python cour...
# 81_D57_origrot45_image.jpg       C:\Users\martar\OneDrive\Documents\Python cour...
# 7_NM3_origrot90_image.jpg        C:\Users\martar\OneDrive\Documents\Python cour...
# 29_D11_origcrop_image.jpg        C:\Users\martar\OneDrive\Documents\Python cour...
# test0_AMM1_orig.jpg              C:\Users\martar\OneDrive\Documents\Python cour...
# test75_SSM30_2_orig.jpg          C:\Users\martar\OneDrive\Documents\Python cour...
# 77_D54_orig.jpg                  C:\Users\martar\OneDrive\Documents\Python cour...
# 45_LMM2_origaffine_image.jpg     C:\Users\martar\OneDrive\Documents\Python cour...
# 7_NM3_orig.jpg                   C:\Users\martar\OneDrive\Documents\Python cour...
# 10_33_origrot90_image.jpg        C:\Users\martar\OneDrive\Documents\Python cour...
# 52_D33_origrot90_image.jpg       C:\Users\martar\OneDrive\Documents\Python cour...
# 113_SSM85_2_origcrop_image.jpg   C:\Users\martar\OneDrive\Documents\Python cour...
# 65_D45_2_origfliphor_image.jpg   C:\Users\martar\OneDrive\Documents\Python cour...
# 93_SSM55_2_origaffine_image.jpg  C:\Users\martar\OneDrive\Documents\Python cour...
# 23_7_origrot90_image.jpg         C:\Users\martar\OneDrive\Documents\Python cour...
# test22_SSM20_orig.jpg            C:\Users\martar\OneDrive\Documents\Python cour...
# 69_SSM26_origaffine_image.jpg    C:\Users\martar\OneDrive\Documents\Python cour...
# 27_D10_origfliphor_image.jpg     C:\Users\martar\OneDrive\Documents\Python cour...
# 38_SSM3_origaffine_image.jpg     C:\Users\martar\OneDrive\Documents\Python cour...
# 61_SSM19_origfliphor_image.jpg   C:\Users\martar\OneDrive\Documents\Python cour...
# 52_D33_origaffine_image.jpg      C:\Users\martar\OneDrive\Documents\Python cour...
# ...                                                                            ...
# 9_32_origrot45_image.jpg         C:\Users\martar\OneDrive\Documents\Python cour...
# 80_D57_2_origaffine_image.jpg    C:\Users\martar\OneDrive\Documents\Python cour...
# 85_SSM40_origfliphor_image.jpg   C:\Users\martar\OneDrive\Documents\Python cour...
# 3_LMM4_origrot90_image.jpg       C:\Users\martar\OneDrive\Documents\Python cour...
# 53_NM83_orig.jpg                 C:\Users\martar\OneDrive\Documents\Python cour...
# 48_D28_2_origrot45_image.jpg     C:\Users\martar\OneDrive\Documents\Python cour...
# 11_34_origaffine_image.jpg       C:\Users\martar\OneDrive\Documents\Python cour...
# 37_D19_2_origaffine_image.jpg    C:\Users\martar\OneDrive\Documents\Python cour...
# 31_SSM29_origrot45_image.jpg     C:\Users\martar\OneDrive\Documents\Python cour...
# 8_29_origrot45_image.jpg         C:\Users\martar\OneDrive\Documents\Python cour...
# 52_NM61_origrot90_image.jpg      C:\Users\martar\OneDrive\Documents\Python cour...
# 23_SSM21_origrot45_image.jpg     C:\Users\martar\OneDrive\Documents\Python cour...
# 100_SSM65_origaffine_image.jpg   C:\Users\martar\OneDrive\Documents\Python cour...
# 32_SSM2_origcrop_image.jpg       C:\Users\martar\OneDrive\Documents\Python cour...
# 61_D40_origrot90_image.jpg       C:\Users\martar\OneDrive\Documents\Python cour...
# 33_SSM30_orig.jpg                C:\Users\martar\OneDrive\Documents\Python cour...
# 70_D51_1_origcrop_image.jpg      C:\Users\martar\OneDrive\Documents\Python cour...
# 66_SSM23_origflip_image.jpg      C:\Users\martar\OneDrive\Documents\Python cour...
# 37_SSM34_origaffine_image.jpg    C:\Users\martar\OneDrive\Documents\Python cour...
# 18_SSM17_origcrop_image.jpg      C:\Users\martar\OneDrive\Documents\Python cour...
# 57_D38_2_origflip_image.jpg      C:\Users\martar\OneDrive\Documents\Python cour...
# 101_SSM68_origfliphor_image.jpg  C:\Users\martar\OneDrive\Documents\Python cour...
# 21_4_origrot45_image.jpg         C:\Users\martar\OneDrive\Documents\Python cour...
# 33_SSM30_origaffine_image.jpg    C:\Users\martar\OneDrive\Documents\Python cour...
# 15_SSM14_origaffine_image.jpg    C:\Users\martar\OneDrive\Documents\Python cour...
# test114_SSM85_orig.jpg           C:\Users\martar\OneDrive\Documents\Python cour...
# 35_SSM32_origrot90_image.jpg     C:\Users\martar\OneDrive\Documents\Python cour...
# 15_41_orig.jpg                   C:\Users\martar\OneDrive\Documents\Python cour...
# 110_SSM7_origaffine_image.jpg    C:\Users\martar\OneDrive\Documents\Python cour...
# 10_33_origrot45_image.jpg        C:\Users\martar\OneDrive\Documents\Python cour...
#
#                                  xmin_norm  ymin_norm  box_width  box_height
# filename
# 44_D24_origrot90_image.jpg        0.468750   0.380208   0.109375    0.244792
# 19_48_origcrop_image.jpg          0.000000   0.208333   0.994792    0.786458
# 11_SSM10_origflip_image.jpg       0.140625   0.166667   0.635417    0.609375
# 5_25_orig.jpg                     0.203125   0.302083   0.588542    0.276042
# 18_46_origaffine_image.jpg        0.317708   0.286458   0.526042    0.421875
# 80_D57_2_orig.jpg                 0.291667   0.458333   0.437500    0.140625
# 85_SSM40_origflip_image.jpg       0.401042   0.369792   0.312500    0.229167
# 118_SSM9_origrot90_image.jpg      0.432292   0.385417   0.145833    0.250000
# 40_SSM5_origrot45_image.jpg       0.000000   0.000000   0.713542    0.994792
# 52_NM61_origflip_image.jpg        0.307292   0.411458   0.526042    0.156250
# 81_D57_origrot45_image.jpg        0.395833   0.385417   0.270833    0.270833
# 7_NM3_origrot90_image.jpg         0.281250   0.109375   0.484375    0.723958
# 29_D11_origcrop_image.jpg         0.395833   0.359375   0.218750    0.166667
# test0_AMM1_orig.jpg               0.380208   0.479167   0.463542    0.197917
# test75_SSM30_2_orig.jpg           0.447917   0.364583   0.302083    0.411458
# 77_D54_orig.jpg                   0.401042   0.375000   0.354167    0.161458
# 45_LMM2_origaffine_image.jpg      0.411458   0.067708   0.296875    0.588542
# 7_NM3_orig.jpg                    0.109375   0.229167   0.723958    0.484375
# 10_33_origrot90_image.jpg         0.416667   0.239583   0.406250    0.541667
# 52_D33_origrot90_image.jpg        0.447917   0.432292   0.104167    0.250000
# 113_SSM85_2_origcrop_image.jpg    0.218750   0.296875   0.776042    0.296875
# 65_D45_2_origfliphor_image.jpg    0.265625   0.411458   0.489583    0.234375
# 93_SSM55_2_origaffine_image.jpg   0.177083   0.208333   0.750000    0.526042
# 23_7_origrot90_image.jpg          0.276042   0.083333   0.447917    0.859375
# test22_SSM20_orig.jpg             0.286458   0.359375   0.520833    0.494792
# 69_SSM26_origaffine_image.jpg     0.083333   0.145833   0.796875    0.510417
# 27_D10_origfliphor_image.jpg      0.354167   0.317708   0.250000    0.156250
# 38_SSM3_origaffine_image.jpg      0.000000   0.000000   0.994792    0.994792
# 61_SSM19_origfliphor_image.jpg    0.500000   0.312500   0.265625    0.333333
# 52_D33_origaffine_image.jpg       0.395833   0.411458   0.385417    0.166667
# ...                                    ...        ...        ...         ...
# 9_32_origrot45_image.jpg          0.385417   0.546875   0.250000    0.177083
# 80_D57_2_origaffine_image.jpg     0.182292   0.432292   0.666667    0.223958
# 85_SSM40_origfliphor_image.jpg    0.281250   0.395833   0.312500    0.229167
# 3_LMM4_origrot90_image.jpg        0.177083   0.354167   0.354167    0.406250
# 53_NM83_orig.jpg                  0.187500   0.385417   0.463542    0.229167
# 48_D28_2_origrot45_image.jpg      0.312500   0.239583   0.385417    0.588542
# 11_34_origaffine_image.jpg        0.151042   0.213542   0.843750    0.552083
# 37_D19_2_origaffine_image.jpg     0.223958   0.286458   0.609375    0.359375
# 31_SSM29_origrot45_image.jpg      0.276042   0.338542   0.427083    0.333333
# 8_29_origrot45_image.jpg          0.307292   0.401042   0.401042    0.333333
# 52_NM61_origrot90_image.jpg       0.411458   0.307292   0.156250    0.526042
# 23_SSM21_origrot45_image.jpg      0.000000   0.000000   0.583333    0.609375
# 100_SSM65_origaffine_image.jpg    0.260417   0.286458   0.526042    0.312500
# 32_SSM2_origcrop_image.jpg        0.000000   0.114583   0.994792    0.880208
# 61_D40_origrot90_image.jpg        0.411458   0.406250   0.135417    0.171875
# 33_SSM30_orig.jpg                 0.218750   0.364583   0.453125    0.229167
# 70_D51_1_origcrop_image.jpg       0.375000   0.421875   0.515625    0.218750
# 66_SSM23_origflip_image.jpg       0.348958   0.416667   0.239583    0.119792
# 37_SSM34_origaffine_image.jpg     0.161458   0.057292   0.526042    0.937500
# 18_SSM17_origcrop_image.jpg       0.276042   0.250000   0.578125    0.307292
# 57_D38_2_origflip_image.jpg       0.380208   0.411458   0.208333    0.187500
# 101_SSM68_origfliphor_image.jpg   0.354167   0.390625   0.333333    0.156250
# 21_4_origrot45_image.jpg          0.473958   0.447917   0.161458    0.171875
# 33_SSM30_origaffine_image.jpg     0.072917   0.291667   0.692708    0.354167
# 15_SSM14_origaffine_image.jpg     0.161458   0.489583   0.796875    0.390625
# test114_SSM85_orig.jpg            0.395833   0.395833   0.296875    0.119792
# 35_SSM32_origrot90_image.jpg      0.312500   0.338542   0.328125    0.437500
# 15_41_orig.jpg                    0.369792   0.348958   0.348958    0.343750
# 110_SSM7_origaffine_image.jpg     0.401042   0.411458   0.208333    0.187500
# 10_33_origrot45_image.jpg         0.322917   0.000000   0.671875    0.661458
#
# [1190 rows x 12 columns]

# %%
test_list = [filename for filename in entry_df.index.values if 'test' in filename]
train_list = [filename for filename in entry_df.index.values if 'test' not in filename]

# %%
X_train = entry_df.loc[train_list]
X_test = entry_df.loc[test_list]

# %%
X_train.shape, X_test.shape
# Out:
# ((1148, 12), (42, 12))

# %%
#now we have to save those files in a folder call training and ensure we are loading the files into that directory
X_train.to_csv('C:\\Users\\martar\\OneDrive\\Documents\\Python course\\ADS\\Final Project\\preprocessed_data\\train_labels.csv')
X_test.to_csv('C:\\Users\\martar\\OneDrive\\Documents\\Python course\\ADS\\Final Project\\preprocessed_data\\test_labels.csv')
